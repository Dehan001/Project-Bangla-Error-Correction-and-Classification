# %%
# !git clone https://github.com/Dehan001/Project-Bangla-Error-Correction-and-Classification.git
# Out:
# Cloning into 'Project-Bangla-Error-Correction-and-Classification'...
# remote: Enumerating objects: 267, done.
# remote: Counting objects: 100% (267/267), done.
# remote: Compressing objects: 100% (264/264), done.
# remote: Total 267 (delta 3), reused 263 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (267/267), 4.32 MiB | 13.63 MiB/s, done.
# Resolving deltas: 100% (3/3), done.

# %%
import glob
import pandas as pd

# Get list of all CSV files inside the Dataset folder
file_list = glob.glob('/content/Project-Bangla-Error-Correction-and-Classification/Dataset/*.csv')
file_list

# Merge all CSV files
merged_df = pd.concat([pd.read_csv(file) for file in file_list], ignore_index=True)

# Save the merged file
merged_df.to_csv('/content/25kdataset_output.csv', index=False)

# %%
len(merged_df)
# Out:
# 25106

# %%
merged_df.head()
# Out:
#       Video ID             Channel name     Time of Publishing  \
# 0  7QHR16rEt3E              Laser Vision  2017-12-14T14:34:51Z
# 1  Y0_BuJF2DPc                 Jamuna TV  2023-11-27T09:12:32Z
# 2  wOr8GVI-1OU             Elias Hossain  2022-01-30T10:02:28Z
# 3  6HSUNn4oJe4          Ridoy The Sailor  2023-07-03T12:30:03Z
# 4  cqoXTyiSoKM  Cinemawala Entertainment  2020-10-17T12:04:36Z
#
#                                                Title          Genre  \
# 0  Guerrilla | Bangla Movie |  Joya Ahsan, Ferdou...  Entertainment
# 1  ফেরদৌসকে নিয়া যা বললেন নুর | Nur vs Ferdous | ...       Politics
# 2  সত্যকে ঢেকে মিথ্যা শেখানো হচ্ছে আমাদের, সত্য জ...  Miscellaneous
# 3           জাহাজে সারাদিন কি করি ? RIDOY THE SAILOR  Entertainment
# 4  যেমন কর্ম তেমন ফল 😋😋 যারা দূরে চলে গিয়ে আবার ফ...  Entertainment
#
#                                              Comment  \
# 0  শরীরের পশম দাঁড়িয়ে যায়, ছবিটি দেখলে,এতটা মায়া ...
# 1            কিছু কইলাম না, কইলে নূর ভাই বেজার হইবো😂
# ...
